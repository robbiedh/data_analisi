# %%
# lakukan testing dulu 
import pandas as pd 
import numpy as np 
from collections import Counter


#  Mmebaca file  csv yang akan  
df  = pd.read_csv('Data/listings.csv')
#  df = df [['id ', Name , Summary , longitude , latitude , space descrp, instant_bookabel ]]

# Ganti kolom  Nan Dengan  0
df.fillna(0, inplace=True)

#mengekstrak kolom  price 
price = df['price']
prices = []

# konversi string ke float

for p in price :
    p = float(p[1:].replace(',',''))
    prices.append(p)
    
#ganti  kolom  price dengan yang baru 
df['price']=prices

#mengabil data yang tidak kosong 
df  = df[df.bathrooms > 0]
df = df[df.bedrooms> 0]
df =df[df.beds >0]
df =df[df.price >0]
df =df[df.review_scores_rating >0]
df =df[df.reviews_per_month >0]
df =df[df.accommodates >0]
df.head()
# Out:
#          id                            listing_url       scrape_id  \
# 1   3075044   https://www.airbnb.com/rooms/3075044  20160906204935
# 2      6976      https://www.airbnb.com/rooms/6976  20160906204935
# 3   1436513   https://www.airbnb.com/rooms/1436513  20160906204935
# 4   7651065   https://www.airbnb.com/rooms/7651065  20160906204935
# 5  12386020  https://www.airbnb.com/rooms/12386020  20160906204935
#
#   last_scraped                                           name  \
# 1   2016-09-07              Charming room in pet friendly apt
# 2   2016-09-07               Mexican Folk Art Haven in Boston
# 3   2016-09-07  Spacious Sunny Bedroom Suite in Historic Home
# 4   2016-09-07                            Come Home to Boston
# 5   2016-09-07                 Private Bedroom + Great Coffee
#
#                                              summary  \
# 1  Charming and quiet room in a second floor 1910...
# 2  Come stay with a friendly, middle-aged guy in ...
# ...

# %%
#menapilkan   berapaa banyak  rooms yang ada 
room_type_df=df.groupby('room_type').id.count()
room_type_df = room_type_df.reset_index()
room_type_df= room_type_df.rename(columns={'id': 'numberf_of_listing'})
room_type_df
# Out:
#          room_type  numberf_of_listing
# 0  Entire home/apt                1393
# 1     Private room                1061
# 2      Shared room                  52

# %%
# membuat  grafik 
import  matplotlib
import matplotlib.pyplot as plt 

matplotlib.style.use('ggplot')
room = df.room_type
r = Counter(room)

room_df=pd.DataFrame.from_dict(r, orient = 'index').sort_values(by=0)
room_df.columns = ['room_type']
room_df.plot.pie(y='room_type',
                colormap='Blues_r',
                figsize=(10,10),
                fontsize=10, autopct ='%.2f',
                legend=False,
                title='Room Type Distributions')

# %%
# membuat  grafik 
import  matplotlib
import matplotlib.pyplot as plt 

#membuat  group dataframe  dari tipe propertis
property_type_df  =df.groupby('property_type').id.count()
property_type_df = property_type_df.reset_index()
property_type_df = property_type_df.rename(columns={'id':'number_of_listing'})

objects =property_type_df['property_type']
y_pos = property_type_df['number_of_listing']

# plot  ke diagram  bar 
property_type_df.plot.bar(x='property_type',
                         y='number_of_listing',
                         figsize= (15, 8),
                         title = 'Frekuensi Jenis  Propertis di  Boston ', 
                         legend = False )

# %%
room_property_df= df.groupby(['property_type', 'room_type']).price.mean()
room_property_df = room_property_df.reset_index()
room_property_df = room_property_df.sort_values('price', ascending=[0])
room_property_df
# Out:
#       property_type        room_type       price
# 22        Townhouse  Entire home/apt  320.800000
# 13       Guesthouse  Entire home/apt  289.000000
# 7              Boat     Private room  287.000000
# 14            House  Entire home/apt  286.809917
# 6              Boat  Entire home/apt  275.222222
# 17             Loft  Entire home/apt  240.750000
# 24            Villa  Entire home/apt  240.000000
# 8       Condominium  Entire home/apt  239.559633
# 1         Apartment  Entire home/apt  224.549107
# 20            Other     Private room  177.428571
# 4   Bed & Breakfast  Entire home/apt  142.500000
# 0                 0     Private room  115.000000
# 5   Bed & Breakfast     Private room  112.230769
# 18             Loft     Private room  108.000000
# 9       Condominium     Private room  105.482759
# 23        Townhouse     Private room  102.531250
# 2         Apartment     Private room   89.298635
# 15            House     Private room   81.106195
# ...

# %%
# from  bokeh.charts import  Donut,show,output_notebook

# output_notebook()
# input=inputDF[(inputDF.property_type!=0)]
# d= Donut(inputDF.groupby(['propery_type','room_type']).price.mean(), hover_text='mean', width=50)
# show(d)



from bokeh.plotting import Donut,figure, output_file, show
output_notebook()
input=df[(df.property_type!=0)]
 d= Donut(df.groupby(['propery_type','room_type']).price.mean(), hover_text='mean', width=50)
show(d)
# Out:
#   File "<ipython-input-23-44e5c3d73865>", line 13
#     d= Donut(df.groupby(['propery_type','room_type']).price.mean(), hover_text='mean', width=50)
#     ^
# IndentationError: unexpected indent

# %%
import  seaborn  as sns
plt.figure(figsize=(12,12))
sns.heatmap(df.groupby(['property_type', 'room_type']).price.mean().unstack(),annot=True,fmt='.0f')

# %%
# heatMap untuk  variasi harga jenis kamar tidur 
plt.figure(figsize=(12,12))
sns.heatmap(df.groupby(['neighbourhood', 'bedrooms']).price.mean().unstack(),annot=True ,fmt='.0f' )
